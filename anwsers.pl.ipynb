# %%
% Answers for the knowledge base


%%%%%%%%% MARTA %%%%%%%%%
answer(to_learn) :-
  write('Just want to increase my level of knowledge').

answer(interested_AI_DA) :-
  write('I am interested in Artificial Intelligence and Data Analytics').
 

answer(automatization) :-
  write('Automatization').
  
answer(Computer_Vision) :-
  write('Computer vision').
  
answer(Machine_Learning) :-
  write('Machine Learning').
  
% Ya existe pero la pongo aqui comentada para ordenar ideas y conceptos de mi árbol
% answer(no) :-
%   write('No').
  
%%%%%%%%%%%%%%%%%%%%%%%%%


answer(for_my_kids) :-
  write('For my kids').

answer(i_dont_know) :-
  write('I don\'t know').

answer(make_money) :-
  write('Make money').

answer(just_for_fun) :-
  write('Just for fun').

answer(im_interested) :-
  write('I\'m interested').

answer(improve_myself) :-
  write('Improve myself').

answer(doesn_t_matter) :-
  write('Doesn\'t matter, I just want $$$').

answer(gaming) :-
  write('3D/Gaming').

answer(mobile) :-
  write('Mobile').

answer(facebook) :-
  write('Facebook').

answer(google) :-
  write('Google').

answer(microsoft) :-
  write('Microsoft').

answer(apple) :-
  write('Apple').

answer(web) :-
  write('Web').

answer(enterprise) :-
  write('Enterprise').

answer(ios) :-
  write('iOS').

answer(android) :-
  write('Android').

answer(front_end) :-
  write('Front-end (web interface)').

answer(back_end) :-
  write('Back-end ("brain" behind a website)').

answer(startup) :-
  write('Startup').

answer(corporate) :-
  write('Corporate').

answer(im_a_fan) :-
  write('I\'m a fan!').

answer(not_bad) :-
  write('Not Bad').

answer(suck) :-
  write('Suck').

answer(yes) :-
  write('Yes').

answer(no) :-
  write('No').

answer(lego) :-
  write('Lego').

answer(play_doh) :-
  write('Play-Doh').

answer(old_ugly) :-
  write('I\'ve an old & ugly toy, but I love it so much!').

answer(easy_way) :-
  write('The easy way').

answer(best_way) :-
  write('The best way').

answer(harder_way) :-
  write('The slightly harder way').

answer(hardest_way) :-
  write('The really hard way (but easier to pick up other languages in the future)').

answer(auto) :-
  write('Auto').

answer(manual) :-
  write('Manual').
# Out:
# Previously defined clauses of user:answer/1 were retracted:
# :- dynamic answer/1.
#
# answer(for_my_kids) :-
#     write('For my kids').
# answer(i_dont_know) :-
#     write('I don\'t know').
# answer(make_money) :-
#     write('Make money').
# answer(just_for_fun) :-
#     write('Just for fun').
# answer(im_interested) :-
#     write('I\'m interested').
# answer(improve_myself) :-
#     write('Improve myself').
# answer(doesn_t_matter) :-
#     write('Doesn\'t matter, I just want $$$').
# answer(gaming) :-
#     write('3D/Gaming').
# answer(mobile) :-
#     write('Mobile').
# answer(facebook) :-
#     write('Facebook').
# answer(google) :-
#     write('Google').
# answer(microsoft) :-
#     write('Microsoft').
# answer(apple) :-
#     write('Apple').
# answer(web) :-
#     write('Web').
# answer(enterprise) :-
#     write('Enterprise').
# answer(ios) :-
#     write(iOS).
# answer(android) :-
#     write('Android').
# answer(front_end) :-
#     write('Front-end (web interface)').
# answer(back_end) :-
#     write('Back-end ("brain" behind a website)').
# answer(startup) :-
#     write('Startup').
# answer(corporate) :-
#     write('Corporate').
# answer(im_a_fan) :-
#     write('I\'m a fan!').
# answer(not_bad) :-
#     write('Not Bad').
# answer(suck) :-
#     write('Suck').
# answer(yes) :-
#     write('Yes').
# answer(no) :-
#     write('No').
# answer(lego) :-
#     write('Lego').
# answer(play_doh) :-
#     write('Play-Doh').
# answer(old_ugly) :-
#     write('I\'ve an old & ugly toy, but I love it so much!').
# answer(easy_way) :-
#     write('The easy way').
# answer(best_way) :-
#     write('The best way').
# answer(harder_way) :-
#     write('The slightly harder way').
# answer(hardest_way) :-
#     write('The really hard way (but easier to pick up other languages in the future)').
# answer(auto) :-
#     write('Auto').
# answer(manual) :-
#     write('Manual').
# % Asserting clauses for user:answer/1
